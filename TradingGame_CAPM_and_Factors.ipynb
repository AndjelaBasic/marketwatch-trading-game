# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import yfinance as yf
import MCF_INV as inv
import scipy.optimize as sco
import plotly.graph_objects as go

# %% [markdown]
# <font color='DarkViolet ' style="font-size:25px"><b>CAPM and Factor Investing</b></font>

# %%
def erCAPM(ret,market,rf,f=252):
    """Computes expected returns by assuiming that: (1) CAPM holds and (2) arithmetic mean is good estimate of expected value.
    - ret: dataset of returns
    - market: vector of market returns
    - rf: vector of risk-free rate
    - f: optional, frequency at which data is collected (by default it is 252, i.e. dailiy data is assumed)"""
    RmRf=market-rf
    if isinstance(ret,pd.DataFrame):
        b=np.array([sm.OLS(ret[r]-rf, RmRf).fit().params['x1'] for r in ret.columns])
        return pd.Series(f*(rf.mean()+b*RmRf.mean()),index=ret.columns)
    else:
        b=sm.OLS(ret-rf, RmRf).fit().params['x1']
        return f*(rf.mean()+b*RmRf.mean())

# %%
def erPCA(ret,rf,f=252,n=None):
    """Computes expected returns based on PCA factor model assuming that arithmetic mean is correct estimate of expected
    returns. Parameters are:
    - ret: dataset of returns
    - rf: vector of risk-free rates
    - f: optional, frequency at which data is collected (by default daily frequency is assumed)
    - n: optional, number of components to be extracted (by default algorithm extract components by Kaisers criterion)"""
    if n!=None and ret.shape[1]<n:
        return print('Wrong input. Desired number of components (n) has to be smaller than or equal to number of stocks')
    else:
        l,evec=np.linalg.eig(ret.cov()*f)
        a=(evec[:,:np.count_nonzero(l>l.mean())] if n==None else evec[:,:n])
        rets_pca=ret@a
        errf,erpca=rf.mean(),rets_pca.mean()
        return [f*(errf+sm.OLS(ret[c]-rf,rets_pca).fit().params@erpca) for c in ret.columns]

# %% [markdown]
# <font color='DarkViolet ' style="font-size:15px"><b>Energy and Technology</b></font>

# %%
stocks = pd.read_csv("Energy and Technology.csv",header=0)
energy = stocks[stocks["Industry"]=="Energy"]["Ticker"].to_list()
tech = stocks[stocks["Industry"]=="Technology"]["Ticker"].to_list()

# %%
prices_energy = yf.download(energy,  start='2022-01-01', end ='2024-04-13' )["Adj Close"] # daily Adj Close prices
prices_tech = yf.download(tech,  start='2022-01-01', end ='2024-04-13')["Adj Close"] # daily Adj Close prices
prices_snp = yf.download("^GSPC", start='2022-01-01', end ='2024-04-13')["Adj Close"]
prices_rf = yf.download("^IRX", start='2022-01-01', end ='2024-04-13')["Adj Close"] # risk free rate, 13 weeks treasury bills
# Out:
# [*********************100%%**********************]  5 of 5 completed
# [*********************100%%**********************]  7 of 7 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# calculate returns
rets_energy = prices_energy.pct_change().dropna()
rets_tech = prices_tech.pct_change().dropna()
rets_snp = prices_snp.pct_change().dropna()
rets_rf = prices_rf.pct_change().dropna()

# %%
# add data energy
basecols_energy  = rets_energy.columns
rets_energy["^GSPC"] = rets_snp
rets_energy["RF"] = rets_rf

for name in rets_energy.columns.drop("RF"):
    rets_energy[name+"rf"] = rets_energy[name] - rets_energy["RF"] 
    
# add data tech
basecols_tech  = rets_tech.columns
rets_tech["^GSPC"] = rets_snp
rets_tech["RF"] = rets_rf

for name in rets_tech.columns.drop("RF"):
    rets_tech[name+"rf"] = rets_tech[name] - rets_tech["RF"] 
    
# add constant
rets_energy  = sm.add_constant(rets_energy)
rets_tech  = sm.add_constant(rets_tech)
    
rets_tech.head()
# Out:
#             const      CLSK       IBM       IOT      ORCL      PATH      QCOM  \
# Date
# 2022-01-04    1.0  0.001043  0.014555 -0.064998  0.010694 -0.031457  0.005478
# 2022-01-05    1.0 -0.107292  0.001449 -0.080703 -0.026789 -0.103318 -0.003899
# 2022-01-06    1.0 -0.031505 -0.020836 -0.000869  0.002322  0.039633 -0.002949
# 2022-01-07    1.0 -0.019277 -0.003768  0.010004  0.013551 -0.010351 -0.029793
# 2022-01-10    1.0 -0.014742  0.001483 -0.009905  0.020226 -0.009694 -0.004046
#
#                 VTSI     ^GSPC        RF    CLSKrf     IBMrf     IOTrf  \
# Date
# 2022-01-04 -0.042194 -0.000630  0.509434 -0.508391 -0.494879 -0.574432
# 2022-01-05 -0.038179 -0.019393  0.062500 -0.169792 -0.061051 -0.143203
# 2022-01-06  0.048855 -0.000964  0.058824 -0.090329 -0.079660 -0.059693
# 2022-01-07 -0.034934 -0.004050 -0.022222  0.002945  0.018454  0.032227
# 2022-01-10  0.004525 -0.001441  0.022727 -0.037469 -0.021244 -0.032633
#
#               ORCLrf    PATHrf    QCOMrf    VTSIrf   ^GSPCrf
# Date
# 2022-01-04 -0.498740 -0.540890 -0.503956 -0.551628 -0.510064
# 2022-01-05 -0.089290 -0.165819 -0.066399 -0.100679 -0.081893
# 2022-01-06 -0.056502 -0.019191 -0.061773 -0.009969 -0.059787
# 2022-01-07  0.035774  0.011871 -0.007571 -0.012712  0.018172
# 2022-01-10 -0.002501 -0.032421 -0.026774 -0.018202 -0.024168

# %%
#energy
modelcols_energy  = rets_energy.columns.where(rets_energy.columns.str.contains("rf")).dropna().drop("^GSPCrf")

for col in modelcols_energy:
    model=sm.OLS(rets_energy[col], rets_energy[['const','^GSPCrf']])  # Specifies the model
    results=model.fit()  # Estimates or fits the model
    print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  MPCrf   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                     3771.
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):          3.20e-253
# Time:                        11:39:40   Log-Likelihood:                 1446.0
# No. Observations:                 571   AIC:                            -2888.
# Df Residuals:                     569   BIC:                            -2879.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      2.166      0.031       0.000       0.003
# ^GSPCrf        0.9581      0.016     61.412      0.000       0.927       0.989
# ==============================================================================
# Omnibus:                       10.176   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               15.546
# Skew:                          -0.111   Prob(JB):                     0.000421
# Kurtosis:                       3.777   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  PSXrf   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.859
# Method:                 Least Squares   F-statistic:                     3465.
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):          3.59e-244
# Time:                        11:39:40   Log-Likelihood:                 1426.8
# No. Observations:                 571   AIC:                            -2850.
# Df Residuals:                     569   BIC:                            -2841.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.001      1.264      0.207      -0.001       0.003
# ^GSPCrf        0.9496      0.016     58.864      0.000       0.918       0.981
# ==============================================================================
# Omnibus:                       38.026   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.910
# Skew:                          -0.394   Prob(JB):                     7.33e-18
# Kurtosis:                       4.642   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  SUNrf   R-squared:                       0.915
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     6138.
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):          5.40e-307
# Time:                        11:39:40   Log-Likelihood:                 1587.6
# No. Observations:                 571   AIC:                            -3171.
# Df Residuals:                     569   BIC:                            -3162.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.001      0.394      0.693      -0.001       0.002
# ^GSPCrf        0.9538      0.012     78.343      0.000       0.930       0.978
# ==============================================================================
# Omnibus:                       15.103   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               28.826
# Skew:                          -0.098   Prob(JB):                     5.50e-07
# Kurtosis:                       4.083   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  UGPrf   R-squared:                       0.781
# Model:                            OLS   Adj. R-squared:                  0.781
# Method:                 Least Squares   F-statistic:                     2032.
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):          6.43e-190
# Time:                        11:39:40   Log-Likelihood:                 1258.6
# No. Observations:                 571   AIC:                            -2513.
# Df Residuals:                     569   BIC:                            -2505.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.001      1.253      0.211      -0.001       0.004
# ^GSPCrf        0.9763      0.022     45.076      0.000       0.934       1.019
# ==============================================================================
# Omnibus:                       33.249   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              115.424
# Skew:                           0.022   Prob(JB):                     8.63e-26
# Kurtosis:                       5.202   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  VLOrf   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     2579.
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):          1.59e-213
# Time:                        11:39:40   Log-Likelihood:                 1344.3
# No. Observations:                 571   AIC:                            -2685.
# Df Residuals:                     569   BIC:                            -2676.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.001      1.202      0.230      -0.001       0.003
# ^GSPCrf        0.9467      0.019     50.785      0.000       0.910       0.983
# ==============================================================================
# Omnibus:                       19.136   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.987
# Skew:                          -0.118   Prob(JB):                     1.26e-09
# Kurtosis:                       4.291   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# <font color='crimson'>
#     aphpa significant:
#     <br>
#     alpha not significant: MPC, PSX, SUN, UGP, VLO
#     <br>
#     beta significant: MPC, PSX, SUN,  UGP, VLO
#     <br>
#     beta not significant:
#     <br><br>
#     Conclusion: CAPM holds for all!
# </font>

# %%
#tech
modelcols_tech = rets_tech.columns.where(rets_tech.columns.str.contains("rf")).dropna().drop("^GSPCrf")

for col in modelcols_tech:
    model=sm.OLS(rets_tech[col], rets_tech[['const','^GSPCrf']])  # Specifies the model
    results=model.fit()  # Estimates or fits the model
    print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 CLSKrf   R-squared:                       0.420
# Model:                            OLS   Adj. R-squared:                  0.419
# Method:                 Least Squares   F-statistic:                     412.4
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):           2.31e-69
# Time:                        11:40:04   Log-Likelihood:                 754.60
# No. Observations:                 571   AIC:                            -1505.
# Df Residuals:                     569   BIC:                            -1497.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0035      0.003      1.270      0.204      -0.002       0.009
# ^GSPCrf        1.0632      0.052     20.307      0.000       0.960       1.166
# ==============================================================================
# Omnibus:                       88.433   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.896
# Skew:                           0.905   Prob(JB):                     1.56e-36
# Kurtosis:                       4.911   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  IBMrf   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     9134.
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):               0.00
# Time:                        11:40:04   Log-Likelihood:                 1688.0
# No. Observations:                 571   AIC:                            -3372.
# Df Residuals:                     569   BIC:                            -3363.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.001      0.718      0.473      -0.001       0.001
# ^GSPCrf        0.9759      0.010     95.572      0.000       0.956       0.996
# ==============================================================================
# Omnibus:                      175.602   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3195.137
# Skew:                           0.857   Prob(JB):                         0.00
# Kurtosis:                      14.461   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  IOTrf   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.611
# Method:                 Least Squares   F-statistic:                     897.4
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):          4.57e-119
# Time:                        11:40:04   Log-Likelihood:                 997.08
# No. Observations:                 571   AIC:                            -1990.
# Df Residuals:                     569   BIC:                            -1981.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.002      0.797      0.426      -0.002       0.005
# ^GSPCrf        1.0258      0.034     29.957      0.000       0.959       1.093
# ==============================================================================
# Omnibus:                      176.659   Durbin-Watson:                   1.857
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              976.425
# Skew:                           1.252   Prob(JB):                    9.37e-213
# Kurtosis:                       8.896   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ORCLrf   R-squared:                       0.917
# Model:                            OLS   Adj. R-squared:                  0.917
# Method:                 Least Squares   F-statistic:                     6321.
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):          2.55e-310
# Time:                        11:40:04   Log-Likelihood:                 1571.8
# No. Observations:                 571   AIC:                            -3140.
# Df Residuals:                     569   BIC:                            -3131.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.001      0.890      0.374      -0.001       0.002
# ^GSPCrf        0.9950      0.013     79.502      0.000       0.970       1.020
# ==============================================================================
# Omnibus:                      221.165   Durbin-Watson:                   2.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14160.735
# Skew:                          -0.824   Prob(JB):                         0.00
# Kurtosis:                      27.341   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 PATHrf   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     1128.
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):          3.68e-137
# Time:                        11:40:04   Log-Likelihood:                 1047.9
# No. Observations:                 571   AIC:                            -2092.
# Df Residuals:                     569   BIC:                            -2083.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.922e-05      0.002     -0.024      0.981      -0.003       0.003
# ^GSPCrf        1.0524      0.031     33.592      0.000       0.991       1.114
# ==============================================================================
# Omnibus:                      106.776   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1156.942
# Skew:                           0.445   Prob(JB):                    5.93e-252
# Kurtosis:                       9.916   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 QCOMrf   R-squared:                       0.900
# Model:                            OLS   Adj. R-squared:                  0.900
# Method:                 Least Squares   F-statistic:                     5149.
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):          2.71e-287
# Time:                        11:40:04   Log-Likelihood:                 1490.4
# No. Observations:                 571   AIC:                            -2977.
# Df Residuals:                     569   BIC:                            -2968.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.001      0.506      0.613      -0.001       0.002
# ^GSPCrf        1.0357      0.014     71.759      0.000       1.007       1.064
# ==============================================================================
# Omnibus:                       40.538   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              127.662
# Skew:                          -0.261   Prob(JB):                     1.90e-28
# Kurtosis:                       5.257   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 VTSIrf   R-squared:                       0.608
# Model:                            OLS   Adj. R-squared:                  0.608
# Method:                 Least Squares   F-statistic:                     884.3
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):          5.87e-118
# Time:                        11:40:04   Log-Likelihood:                 1018.6
# No. Observations:                 571   AIC:                            -2033.
# Df Residuals:                     569   BIC:                            -2025.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.002      0.790      0.430      -0.002       0.005
# ^GSPCrf        0.9806      0.033     29.738      0.000       0.916       1.045
# ==============================================================================
# Omnibus:                      452.294   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14736.374
# Skew:                           3.171   Prob(JB):                         0.00
# Kurtosis:                      27.066   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# <font color='crimson'>
#     aphpa significant:
#     <br>
#     alpha not significant: CLS,  IBM, IOT, ORC,PATH,  QCOM,VTSI
#     <br>
#     beta significant: CLS, IBM,IOT, ORC, PATH,  QCOM,VTSI
#     <br>
#     beta not significant:
#     <br><br>
#     Conclusion: CAPM holds for all!
# </font>

# %%
# re-estimate the models without intercept and get expected return with CAPM

# energy
eret_energy_list = []
for col in basecols_energy:
    eret_energy_list.append(erCAPM(rets_energy[col], rets_energy["^GSPC"], rets_energy["RF"]))
    
# tech
eret_tech_list = []
for col in basecols_tech:
    eret_tech_list.append(erCAPM(rets_tech[col], rets_tech["^GSPC"], rets_tech["RF"]))

eret_energy = pd.DataFrame(eret_energy_list, index =basecols_energy, columns = ["ER"])
eret_tech = pd.DataFrame(eret_tech_list, index =basecols_tech,  columns = ["ER"])

# %%
eret_energy
# Out:
#               ER
# Ticker
# MPC     0.154656
# PSX     0.168568
# SUN     0.153139
# UGP     0.110805
# VLO     0.175979

# %%
eret_tech
# Out:
#               ER
# Ticker
# CLSK   -0.070939
# IBM     0.103916
# IOT    -0.001285
# ORCL    0.062144
# PATH   -0.072393
# QCOM   -0.031624
# VTSI    0.100614

# %%
# weights for energy
# can change desired expected return

inv.targetP(ret=rets_energy[basecols_energy],mi=0.1,Bounds = [0,1],er_assumed=eret_energy["ER"])
# Out:
# {'w': array([3.86537744e-18, 1.06084097e-13, 2.90940057e-14, 1.00000000e+00,
#         4.17630601e-19]),
#  'er': 0.1,
#  'vol': 0.4463775364571848}

# %%
# weights for tech
# can change desired expected return

inv.targetP(ret=rets_tech[basecols_tech],mi=0.15, Bounds=[0,1], er_assumed=eret_tech["ER"])
# Out:
# {'w': array([2.51846421e-19, 1.00000000e+00, 1.64523059e-16, 2.18715438e-13,
#         3.74245051e-13, 2.48460000e-17, 9.11467046e-14]),
#  'er': 0.15,
#  'vol': 0.21092299297503747}

# %%
# PCA tech
PCA_exp_ret_tech=erPCA(rets_tech[basecols_tech],rets_tech["RF"])  #Expected returns estimationl using PCA method
PCA_exp_ret_tech
# Out:
# [3.0377490308845028,
#  2.3248978791595,
#  2.511976294917787,
#  2.346979787996739,
#  2.5586090506378247,
#  2.403115457359172,
#  2.3545166177743924]

# %%
# PCA weights for tech
# can change desired expected return

inv.targetP(ret=rets_tech[basecols_tech],mi=0.15, Bounds=[0,1], er_assumed=PCA_exp_ret_tech)
# Out:
# {'w': array([2.09973403e-17, 1.00000000e+00, 6.12621972e-13, 7.24249128e-17,
#         6.10353568e-17, 1.55730058e-17, 3.78672041e-16]),
#  'er': 0.15,
#  'vol': 0.21092299297501574}

# %%
# PCA energy
PCA_exp_ret_energy=erPCA(rets_energy[basecols_energy],rets_energy["RF"])  #Expected returns estimationl using PCA method
PCA_exp_ret_energy
# Out:
# [2.6808674168368123,
#  2.6762902058474345,
#  2.4345295427527827,
#  2.6762538691013775,
#  2.762968130392645]

# %%
# PCA weights for energy
# can change desired expected return
inv.targetP(ret=rets_energy[basecols_energy],mi=0.1, Bounds=[0,1], er_assumed=PCA_exp_ret_energy)
# Out:
# {'w': array([2.13031685e-17, 5.15699089e-17, 1.00000000e+00, 5.78958120e-17,
#         4.13792567e-17]),
#  'er': 0.1,
#  'vol': 0.23677703349990575}

# %% [markdown]
# <font color='DarkViolet ' style="font-size:15px"><b>CAPM and Factor Investing do not give great results!</b></font>
